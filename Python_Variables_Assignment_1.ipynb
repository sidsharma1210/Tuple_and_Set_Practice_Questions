# %% [markdown]
# <a href="https://colab.research.google.com/github/sidsharma1210/PYTHON/blob/main/Python_Variables_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Variables Practice (Assignment 1)
#
# **Topics Covered:**
# - Variable creation
# - int, float, str, bool data types
# - Printing variables
# - f-strings

# %% [markdown]
# ## Section 1: Variable Creation & Printing

# %% [markdown]
# ### Question 1
# Create a variable to store your **age** and print it.

# %%
# write your answer

age =35

print(age)
# Out:
# 35

# %% [markdown]
# ### Question 2
# Create a variable to store the **price of a notebook** (can be a decimal value) and print it.

# %%
# write your answer
price = 10.5

print(price)
# Out:
# 10.5

# %% [markdown]
# ### Question 3
# Create a variable to store your **first name** and print it.

# %%
# write your answer
first_name = "siddhartha"

print(first_name)
# Out:
# siddhartha

# %% [markdown]
# ### Question 4
# Create a variable to store whether you have **completed today’s class** (True/False) and print it.

# %%
# write your answer
today_class = True
print(today_class)
# Out:
# True

# %% [markdown]
# ### Question 5
# Create two variables:
# - one to store the **number of classes attended**
# - one to store the **average rating** (float)
# Print both.

# %%
# write your answer
number_of_classes_attended = 2
average_rating = 3.5
print(number_of_classes_attended)
print(average_rating)
# Out:
# 2
# 3.5

# %% [markdown]
# ## Section 2: Printing using f-strings

# %% [markdown]
# ### Question 6
# Create variables for **name** and **age** and print:
# > My name is Rahul and I am 22 years old.

# %%
# write your answer
name = "siddhartha"
age = 22
print(f"My name is {name} and I am {age} years old")
# Out:
# My name is siddhartha and I am 22 years old

# %% [markdown]
# ### Question 7
# Create variables for **item name** and **price** and print:
# > The price of Pen is 10.5 rupees.

# %%
item_name = "Pen"
price = 10.5
print(f"The price of {item_name} is {price} rupees.")
# Out:
# The price of Pen is 10.5 rupees.

# %% [markdown]
# ### Question 8
# Create variables for **batch name** and **class completed status** and print:
# > Batch DA10 class completed status is True.

# %%
Batch_name = "DA10"
class_completed_status = True
print(f"Batch {Batch_name} class completed status is {class_completed_status}")
# Out:
# Batch DA10 class completed status is True
