# %% [markdown]
# <a href="https://colab.research.google.com/github/sidsharma1210/Tuple_and_Set_Practice_Questions/blob/main/python_sets_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Python Sets – Practice Questions

# %% [markdown]
# ### Q1
# Create a set from the list below and print only the unique values.
#
# ```python
# data = [10, 20, 20, 30, 40, 40]
# ```

# %%
data = [10, 20, 20, 30, 40, 40]
set1 = set(data)
print(set1)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### Q2
# What will be the output? Explain why.
#
# ```python
# s = {1, 2, 3, 3, 2}
# print(s)
# ```

# %%
s = {1, 2, 3, 3, 2}
print(s)    # because s is set here and this deletes repetations
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3
# Create an empty set and add numbers from 1 to 5 using a loop.

# %%
s = set()
for i in range(1,6):
  s.add(i)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ### Q4
# Why does this code give an error? Fix it.
#
# ```python
# s = {}
# s.add(10)
# ```

# %%
s = {}
s.add(10)       #gives error because s is dictionary
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1898770677.py in <cell line: 0>()
#       1 s = {}
# ----> 2 s.add(10)
#
# AttributeError: 'dict' object has no attribute 'add'

# %% [markdown]
# ### Q5
# Given:
# ```python
# A = {2, 4, 6, 8}
# B = {4, 8, 12}
# ```
# Find Union, Intersection, A-B

# %%
A = {2, 4, 6, 8}
B = {4, 8, 12}
print(A|B)
print(A&B)
print(A-B)
# Out:
# {2, 4, 6, 8, 12}
# {8, 4}
# {2, 6}

# %% [markdown]
# ### Q6
# Check whether 15 exists in the set {5, 10, 15, 20}.

# %%
s = {5, 10, 15, 20}
if 15 in s:
  print("15 exists in the set")
else :
  print("15 does not exist in the set")
# Out:
# 15 exists in the set

# %% [markdown]
# ### Q7
# Remove element 30 safely from {10, 20, 30, 40}.

# %%
s ={10, 20, 30, 40}
if 30 in s:
  s.remove(30)
  print(s)
# Out:
# {40, 10, 20}

# %% [markdown]
# ### Q8
# Count unique elements in:
# ```python
# nums = [1, 2, 2, 3, 4, 4, 5]
# ```

# %%
nums = [1, 2, 2, 3, 4, 4, 5]
s = set(nums)
print(len(s))
# Out:
# 5

# %% [markdown]
# ### Q9
# What will be the output?
# ```python
# s = {10, 20, 30}
# s.add(20)
# print(len(s))
# ```

# %%
s = {10, 20, 30}
s.add(20)
print(len(s))
# Out:
# 3

# %% [markdown]
# ### Q10
# Can a set contain a list? Why?
# ```python
# s = {1, 2, [3, 4]}
# ```

# %%
s = {1, 2, [3, 4]}
print(s)      #set doesn't contain list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3970922041.py in <cell line: 0>()
# ----> 1 s = {1, 2, [3, 4]}
#       2 print(s)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Q11
# Convert {100, 200, 300} into list and print first element.

# %%
 s = {100, 200, 300}
 l = sorted(list(s))
 print(l[0])
# Out:
# 100

# %% [markdown]
# ### Q12
# Students in two classes:
# ```python
# class_A = {'Aman','Riya','Karan','Neha'}
# class_B = {'Neha','Simran','Aman'}
# ```

# %%
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
a= len(class_A|class_B)
print(a)
# Out:
# 5

# %% [markdown]
# ### Q13
# Find unique characters in:
# ```python
# text = 'programming'
# ```

# %%
text = 'programming'
s = set(text)
print(s)
# Out:
# {'g', 'm', 'o', 'i', 'r', 'n', 'a', 'p'}

# %% [markdown]
# ### Q14
# Remove duplicate words from:
# ```python
# sentence = 'python is easy and python is powerful'
# ```

# %%
sentence = 'python is easy and python is powerful'
sentence_1 = sentence.split()
print(sentence_1)
s = set(sentence_1)
print(s)
# Out:
# ['python', 'is', 'easy', 'and', 'python', 'is', 'powerful']
# {'and', 'python', 'easy', 'is', 'powerful'}

# %% [markdown]
# ### Q15
# What is the output?
# ```python
# s = set('hello')
# print(s)
# ```

# %%
s = set('hello')
print(s)  # because set function breaks the strings in letters
# Out:
# {'o', 'h', 'e', 'l'}
